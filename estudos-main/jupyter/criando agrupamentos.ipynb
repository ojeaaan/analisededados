# %%
import pandas as pd

# %%
dados = pd.read_csv("F:/Cursos/ALURA/Formação Data Science/Python Pandas - Tratando e analisando dados/ALURA - JUPYTER/aluguel_residencial_tratado_drop.csv",sep=";")

# %%
dados.head(10)
# Out:
#    Unnamed: 0                Tipo               Bairro  Quartos  Vagas  \
# 0           0           Quitinete           Copacabana        1      0
# 1           1                Casa      Jardim Botânico        2      0
# 2           2         Apartamento               Centro        1      0
# 3           3         Apartamento         Higienópolis        1      0
# 4           4         Apartamento             Cachambi        2      0
# 5           5  Casa de Condomínio      Barra da Tijuca        5      4
# 6           6  Casa de Condomínio                Ramos        2      2
# 7           7         Apartamento               Grajaú        2      1
# 8           8         Apartamento  Lins de Vasconcelos        3      1
# 9           9         Apartamento           Copacabana        1      0
#
#    Suites  Area    Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 0       0    40   1700.0       500.0  60.0     42.50   Apartamento
# ...

# %%
dados['Valor'].mean()
# Out:
# 5046.172821405663

# %%
bairros = ['Barra da Tijuca', 'Copacabana', 'Ipanema', 'Leblon', 'Botafogo', 'Flamengo', 'Tijuca']
selecao = dados['Bairro'].isin(bairros)
dados = dados[selecao]

# %%
dados
# Out:
#        Unnamed: 0                Tipo           Bairro  Quartos  Vagas  \
# 0               0           Quitinete       Copacabana        1      0
# 5               5  Casa de Condomínio  Barra da Tijuca        5      4
# 9               9         Apartamento       Copacabana        1      0
# 10             10           Quitinete       Copacabana        1      0
# 11             11         Apartamento       Copacabana        4      3
# ...           ...                 ...              ...      ...    ...
# 21816       21816         Apartamento           Leblon        3      0
# 21817       21817         Apartamento          Ipanema        3      1
# 21818       21818         Apartamento           Tijuca        1      0
# 21820       21820  Casa de Condomínio  Barra da Tijuca        5      3
# 21825       21825         Apartamento           Leblon        2      0
#
#        Suites  Area    Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# ...

# %%
dados['Bairro'].drop_duplicates()
# Out:
# 0          Copacabana
# 5     Barra da Tijuca
# 15             Tijuca
# 19            Ipanema
# 23           Botafogo
# 27             Leblon
# 78           Flamengo
# Name: Bairro, dtype: object

# %%
grupo_bairro = dados.groupby('Bairro')

# %%
#Só para visualizar
grupo_bairro.groups
# Out:
# {'Barra da Tijuca': [5, 14, 16, 21, 30, 32, 35, 42, 43, 60, 61, 64, 68, 74, 79, 93, 107, 110, 112, 117, 130, 132, 136, 150, 153, 155, 165, 166, 173, 186, 189, 207, 214, 221, 224, 233, 236, 239, 244, 259, 265, 274, 276, 291, 292, 293, 295, 302, 308, 311, 325, 335, 336, 345, 360, 366, 368, 374, 380, 387, 389, 400, 412, 432, 433, 435, 436, 439, 449, 451, 462, 463, 465, 473, 476, 484, 494, 500, 503, 511, 537, 538, 539, 540, 543, 547, 552, 554, 555, 556, 584, 587, 588, 590, 594, 596, 601, 611, 622, 630, ...], 'Botafogo': [23, 48, 87, 88, 111, 119, 127, 134, 196, 200, 225, 334, 362, 415, 416, 498, 524, 526, 545, 593, 649, 685, 719, 756, 765, 822, 827, 861, 915, 924, 928, 1006, 1043, 1080, 1091, 1110, 1116, 1127, 1140, 1165, 1201, 1205, 1223, 1250, 1282, 1295, 1304, 1317, 1348, 1383, 1414, 1419, 1455, 1517, 1529, 1579, 1630, 1655, 1670, 1699, 1741, 1742, 1788, 1814, 1823, 1826, 1853, 1922, 1931, 1957, 1972, 1981, 1989, 2029, 2066, 2069, 2081, 2083, 2084, 2088, 2097, 2148, 2149, 2165, 2179, 
# ...

# %%
for bairro,dados in grupo_bairro:
    print(bairro)
# Out:
# Barra da Tijuca
# Botafogo
# Copacabana
# Flamengo
# Ipanema
# Leblon
# Tijuca

# %%
#aqui dentro de dados é salvo o dataframe, logo é pego o valor e feito a média
for bairro,dados in grupo_bairro:
    print('{} -> {}'.format(bairro,dados.Valor.mean()))
# Out:
# Barra da Tijuca -> 7069.552938130986
# Botafogo -> 8791.828178694159
# Copacabana -> 4126.677004538578
# Flamengo -> 4113.526610644258
# Ipanema -> 9352.001133786847
# Leblon -> 8746.344992050874
# Tijuca -> 2043.52

# %%
grupo_bairro['Valor'].mean()
# Out:
# Bairro
# Barra da Tijuca    7069.552938
# Botafogo           8791.828179
# Copacabana         4126.677005
# Flamengo           4113.526611
# Ipanema            9352.001134
# Leblon             8746.344992
# Tijuca             2043.520000
# Name: Valor, dtype: float64

# %%
grupo_bairro[['Valor','Condominio']].mean().round(2)
# Out:
#                    Valor  Condominio
# Bairro
# Barra da Tijuca  7069.55     3591.01
# Botafogo         8791.83      976.28
# Copacabana       4126.68     1148.68
# Flamengo         4113.53     1102.15
# Ipanema          9352.00     2244.44
# Leblon           8746.34     2107.18
# Tijuca           2043.52      711.69

# %%
import pandas as pd
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])

# %%
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
sexo = alunos.groupby('Sexo')

# %%
sexo = pd.DataFrame(sexo['Notas'].mean().round(2))

# %%
sexo.columns = ['Notas Médias']
sexo
# Out:
#       Notas Médias
# Sexo
# F             5.82
# M             7.12

# %%
sexo = alunos.groupby('Sexo')
sexo = pd.DataFrame(sexo['Notas'].mean().round(2))
sexo.columns = ['Notas Médias']
sexo
# Out:
#       Notas Médias
# Sexo
# F             5.82
# M             7.12

# %% [markdown]
# ## Estatísticas Descritivas

# %%
grupo_bairro['Valor'].describe().round(2)
# Out:
#                   count     mean        std     min     25%     50%      75%  \
# Bairro
# Barra da Tijuca  3863.0  7069.55   11874.15   800.0  2500.0  4500.0   8500.0
# Botafogo          873.0  8791.83  152202.41   700.0  2200.0  3000.0   4350.0
# Copacabana       2644.0  4126.68    3611.41   100.0  2000.0  3000.0   4800.0
# Flamengo          714.0  4113.53    3839.13   800.0  1900.0  2900.0   4975.0
# Ipanema          1764.0  9352.00    8219.72  1200.0  4500.0  7000.0  11000.0
# Leblon           1258.0  8746.34    7004.04   100.0  4500.0  7000.0  10500.0
# Tijuca           1100.0  2043.52    1664.34   750.0  1500.0  1800.0   2300.0
#
#                        max
# Bairro
# Barra da Tijuca   600000.0
# Botafogo         4500000.0
# Copacabana         35000.0
# Flamengo           35000.0
# Ipanema            90000.0
# Leblon            100000.0
# Tijuca             45000.0

# %%
grupo_bairro['Valor'].aggregate(['min','max','sum'])
# Out:
#                     min        max         sum
# Bairro
# Barra da Tijuca   800.0   600000.0  27309683.0
# Botafogo          700.0  4500000.0   7675266.0
# Copacabana        100.0    35000.0  10910934.0
# Flamengo          800.0    35000.0   2937058.0
# Ipanema          1200.0    90000.0  16496930.0
# Leblon            100.0   100000.0  11002902.0
# Tijuca            750.0    45000.0   2247872.0

# %%
grupo_bairro['Valor'].aggregate(['min','max','sum']).rename(columns={'min': 'Mínimo', 'max': 'Máximo', 'sum': 'Soma'})
# Out:
#                  Mínimo     Máximo        Soma
# Bairro
# Barra da Tijuca   800.0   600000.0  27309683.0
# Botafogo          700.0  4500000.0   7675266.0
# Copacabana        100.0    35000.0  10910934.0
# Flamengo          800.0    35000.0   2937058.0
# Ipanema          1200.0    90000.0  16496930.0
# Leblon            100.0   100000.0  11002902.0
# Tijuca            750.0    45000.0   2247872.0

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(20,4))

# %%
grupo_bairro['Valor'].std()
# Out:
# Bairro
# Barra da Tijuca     11874.152437
# Botafogo           152202.407611
# Copacabana           3611.409544
# Flamengo             3839.125142
# Ipanema              8219.718352
# Leblon               7004.042810
# Tijuca               1664.337667
# Name: Valor, dtype: float64

# %%
grupo_bairro['Valor'].std().plot.bar(color = 'blue')
# Out:
# <Axes: xlabel='Bairro'>

# %%
fig = grupo_bairro['Valor'].std().plot.bar(color = 'blue')
fig.set_ylabel('Valor do Alugel')
fig.set_title('Valor Médio do Alugel por bairro', {'fontsize':22})
# Out:
# Text(0.5, 1.0, 'Valor Médio do Alugel por bairro')
