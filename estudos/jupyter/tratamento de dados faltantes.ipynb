# %%
pip install pandas
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...

# %%
import pandas as pd

# %%
alresi = pd.read_csv("F:/Cursos/ALURA/Formação Data Science/Python Pandas - Tratando e analisando dados/ALURA - JUPYTER/aluguel_residencial.csv",sep= ";")

# %%
alresi.isnull()
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Valor  Condominio   IPTU
# 0      False   False    False  False   False  False  False       False  False
# 1      False   False    False  False   False  False  False        True   True
# 2      False   False    False  False   False  False  False       False  False
# 3      False   False    False  False   False  False  False       False   True
# 4      False   False    False  False   False  False  False        True   True
# ...      ...     ...      ...    ...     ...    ...    ...         ...    ...
# 22575  False   False    False  False   False  False  False       False  False
# 22576  False   False    False  False   False  False  False       False  False
# 22577  False   False    False  False   False  False  False       False  False
# 22578  False   False    False  False   False  False  False       False  False
# 22579  False   False    False  False   False  False  False       False   True
#
# [22580 rows x 9 columns]

# %%
alresi.notnull()
# Out:
#        Tipo  Bairro  Quartos  Vagas  Suites  Area  Valor  Condominio   IPTU
# 0      True    True     True   True    True  True   True        True   True
# 1      True    True     True   True    True  True   True       False  False
# 2      True    True     True   True    True  True   True        True   True
# 3      True    True     True   True    True  True   True        True  False
# 4      True    True     True   True    True  True   True       False  False
# ...     ...     ...      ...    ...     ...   ...    ...         ...    ...
# 22575  True    True     True   True    True  True   True        True   True
# 22576  True    True     True   True    True  True   True        True   True
# 22577  True    True     True   True    True  True   True        True   True
# 22578  True    True     True   True    True  True   True        True   True
# 22579  True    True     True   True    True  True   True        True  False
#
# [22580 rows x 9 columns]

# %% [markdown]
# Aqui podemos identificar alguns dados que estão vazios, por exemplo temos o total de 22.580 mil dados, valor/condomínio/IPTU tem alguns faltando

# %%
alresi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22580 entries, 0 to 22579
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        22580 non-null  object
#  1   Bairro      22580 non-null  object
#  2   Quartos     22580 non-null  int64
#  3   Vagas       22580 non-null  int64
#  4   Suites      22580 non-null  int64
#  5   Area        22580 non-null  int64
#  6   Valor       22571 non-null  float64
#  7   Condominio  20765 non-null  float64
#  8   IPTU        15795 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.6+ MB

# %%
alresi['Valor'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 22575    False
# 22576    False
# 22577    False
# 22578    False
# 22579    False
# Name: Valor, Length: 22580, dtype: bool

# %% [markdown]
# Aqui então como retorna falto e true, ou seja todos os valores que são nulos e retornando como um dataframe

# %%
alresi[alresi['Valor'].isnull()]
# Out:
#              Tipo           Bairro  Quartos  Vagas  Suites  Area  Valor  \
# 58    Apartamento  Barra da Tijuca        2      1       1    70    NaN
# 1492  Apartamento             Leme        2      0       0    75    NaN
# 1683         Casa     Campo Grande        3      4       3   363    NaN
# 2012  Apartamento         Botafogo        2      0       0    95    NaN
# 2034  Apartamento       Copacabana        2      0       0    72    NaN
# 4941         Casa     Campo Grande        3      2       1   100    NaN
# 8568  Apartamento             Leme        2      0       1    75    NaN
# 8947  Apartamento           Glória        3      0       1   135    NaN
# 9149  Apartamento            Gávea        3      1       1   105    NaN
#
#       Condominio   IPTU
# 58         970.0   68.0
# 1492       878.0    NaN
# 1683         NaN    NaN
# 2012      1010.0  170.0
# 2034       850.0    NaN
# 4941         NaN    NaN
# 8568       878.0    NaN
# 8947       910.0  228.0
# ...

# %%
a = alresi.shape[0]
a
# Out:
# 22580

# %% [markdown]
# Aqui apagamos todos os dados vazios dentro do dataframe

# %%
a = alresi.shape[0]
alresi.dropna(subset = ['Valor'], inplace= True)
b = alresi.shape[0]
a-b
# Out:
# 9

# %%
alresi[alresi['Valor'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %% [markdown]
# ## Tratamentos de Dados Faltantes (Continuação)

# %%
alresi[alresi['Condominio'].isnull()]
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 1                    Casa           Jardim Botânico        2      0       1
# 4             Apartamento              Vista Alegre        3      1       0
# 6      Casa de Condomínio           Barra da Tijuca        5      4       5
# 7      Casa de Condomínio                     Ramos        2      2       0
# 8             Apartamento                    Centro        1      0       0
# ...                   ...                       ...      ...    ...     ...
# 22510                Casa              Campo Grande        1      0       0
# 22516        Casa de Vila                    Pavuna        2      0       0
# 22535                Casa  Recreio dos Bandeirantes        4      2       2
# 22547                Casa             Bento Ribeiro        2      1       0
# 22558                Casa                    Centro        5      0       1
#
#        Area    Valor  Condominio  IPTU
# ...

# %%
alresi[alresi['Condominio'].isnull()].shape[0]
# Out:
# 1813

# %%
alresi[(alresi['Tipo'] == 'Apartamento') & (alresi['Condominio'].isnull())]
# Out:
#               Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 4      Apartamento     Vista Alegre        3      1       0    70  1200.0
# 8      Apartamento           Centro        1      0       0    36  1200.0
# 83     Apartamento       Praça Seca        2      0       0    80  1000.0
# 117    Apartamento    Rocha Miranda        2      1       0    50  1100.0
# 133    Apartamento  Barra da Tijuca        1      1       1    65  2350.0
# ...            ...              ...      ...    ...     ...   ...     ...
# 22328  Apartamento       Copacabana        3      0       0   130  4600.0
# 22356  Apartamento        Guadalupe        1      0       0    40   550.0
# 22373  Apartamento       Bonsucesso        1      0       0    60  1000.0
# 22403  Apartamento         Flamengo        2      0       0    59  3500.0
# 22474  Apartamento        Cascadura        3      0       1    70  1200.0
#
#        Condominio  IPTU
# 4             NaN   NaN
# 8             NaN   NaN
# ...

# %%
selecao = (alresi['Tipo'] == 'Apartamento') & (alresi['Condominio'].isnull())

# %%
a = alresi.shape[0]
#alresi = alresi[selecao] AQUI EU IREI COLOCAR APENAS OS NULOS E NÃO É OQ QUEREMOS, QUEREMOS COLOCAR APENAS OS TRUE, LOGO COLOQUE O "~"
alresi = alresi[~selecao]
b = alresi.shape[0]
a-b
# Out:
# 745

# %%
alresi[alresi['Condominio'].isnull()].shape[0]
# Out:
# 1068

# %%
alresi[alresi['Condominio'].isnull()]
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 1                    Casa           Jardim Botânico        2      0       1
# 6      Casa de Condomínio           Barra da Tijuca        5      4       5
# 7      Casa de Condomínio                     Ramos        2      2       0
# 14     Casa de Condomínio                   Taquara        3      1       1
# 24                   Casa              Campo Grande        4      1       2
# ...                   ...                       ...      ...    ...     ...
# 22510                Casa              Campo Grande        1      0       0
# 22516        Casa de Vila                    Pavuna        2      0       0
# 22535                Casa  Recreio dos Bandeirantes        4      2       2
# 22547                Casa             Bento Ribeiro        2      1       0
# 22558                Casa                    Centro        5      0       1
#
#        Area    Valor  Condominio  IPTU
# ...

# %%
alresi.fillna(0, inplace= True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17648\1998102080.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alresi.fillna(0, inplace= True)

# %%
alresi[alresi['Tipo'] == 'Casa']
#alresi[(alresi['Tipo'] == 'Apartamento')]
# Out:
#        Tipo                    Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 1      Casa           Jardim Botânico        2      0       1   100   7000.0
# 24     Casa              Campo Grande        4      1       2   400  12000.0
# 56     Casa                     Méier        2      0       0    51   1500.0
# 60     Casa               São Conrado        4      2       4   730  28000.0
# 100    Casa                  Maracanã        8      3       5   259   7000.0
# ...     ...                       ...      ...    ...     ...   ...      ...
# 22452  Casa             Vila da Penha        2      1       0    80   1500.0
# 22510  Casa              Campo Grande        1      0       0    50    600.0
# 22535  Casa  Recreio dos Bandeirantes        4      2       2   352   6500.0
# 22547  Casa             Bento Ribeiro        2      1       0    60   1400.0
# 22558  Casa                    Centro        5      0       1   160   5000.0
#
#        Condominio     IPTU
# ...

# %%
alresi.to_csv("F:/Cursos/ALURA/Formação Data Science/Python Pandas - Tratando e analisando dados/ALURA - JUPYTER/aluguel_residencial_tratado.csv",sep= ";", index= False)
