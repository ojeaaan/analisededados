# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (15,8))

# %%
dados = pd.read_csv("F:/Cursos/ALURA/Formação Data Science/Python Pandas - Tratando e analisando dados/ALURA - JUPYTER/aluguel_residencial_sem_outliers.csv", sep= ";")
dados.head()
# Out:
#    Unnamed: 0         Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           2  Apartamento               Centro        1      0       0    15
# 1           3  Apartamento         Higienópolis        1      0       0    48
# 2           4  Apartamento             Cachambi        2      0       0    50
# 3           7  Apartamento               Grajaú        2      1       0    70
# 4           8  Apartamento  Lins de Vasconcelos        3      1       1    90
#
#     Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 0   800.0       390.0  20.0     53.33   Apartamento
# 1   800.0       230.0   0.0     16.67   Apartamento
# 2  1300.0       301.0  17.0     26.00   Apartamento
# 3  1500.0       642.0  74.0     21.43   Apartamento
# 4  1500.0       455.0  14.0     16.67   Apartamento

# %%
area = plt.figure()

# %%
g1 = area.add_subplot(2, 2, 1)
g2 = area.add_subplot(2, 2, 2)
g3 = area.add_subplot(2, 2, 3)
g4 = area.add_subplot(2, 2, 4)

# %%
g1.scatter(dados.Valor,dados.Area)
g1.set_title('Valor x Área')
# Out:
# Text(0.5, 1.0, 'Valor x Área')

# %%
area

# %%
g2.hist(dados.Valor)
g2.set_title('Histograma')
# Out:
# Text(0.5, 1.0, 'Histograma')

# %%
area

# %% [markdown]
# **Pega números aleatórios**

# %%
dados_g3 = dados.Valor.sample(100) 
dados_g3
# Out:
# 11089    3000.0
# 12307    2350.0
# 2730     1100.0
# 11592    1700.0
# 6854     3500.0
#           ...
# 2947     1300.0
# 11116    1300.0
# 3665     2000.0
# 17907    1700.0
# 11386    6400.0
# Name: Valor, Length: 100, dtype: float64

# %%
g1.scatter(dados.Valor, dados.Area)
g1.set_title('Valor X Área')

g2.hist(dados.Valor)
g2.set_title('Histograma')

dados_g3 = dados.Valor.sample(100) 
dados_g3.index = range(dados_g3.shape[0])
g3.plot(dados_g3)
g3.set_title('Amostra (Valor)')

grupo = dados.groupby('Tipo')['Valor']
label = grupo.mean().index
valores = grupo.mean().values
g4.bar(label, valores)
g4.set_title('Valor Médio por Tipo')
area

# %%
area.savefig('F:/Cursos/ALURA/Formação Data Science/Python Pandas - Tratando e analisando dados/ALURA - JUPYTER/grafico.png', dpi = 300, bbox_inches = 'tight')
